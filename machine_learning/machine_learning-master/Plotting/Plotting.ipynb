# %% [markdown]
# <a href="https://colab.research.google.com/github/deepanrajm/machine_learning/blob/master/Plotting/Plotting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Plotting**

# %%
# !git clone https://github.com/deepanrajm/machine_learning.git
# Out:
# Cloning into 'machine_learning'...
# remote: Enumerating objects: 73096, done.
# remote: Counting objects: 100% (3066/3066), done.
# remote: Compressing objects: 100% (2868/2868), done.
# remote: Total 73096 (delta 215), reused 3034 (delta 191), pack-reused 70030 (from 1)
# Receiving objects: 100% (73096/73096), 127.86 MiB | 10.40 MiB/s, done.
# Resolving deltas: 100% (217/217), done.
# Updating files: 100% (5870/5870), done.

# %% [markdown]
# # General plot.**py**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
x = np.random.random((10, 1))

print(x)
# Out:
# [[0.64908848]
#  [0.80041224]
#  [0.86320114]
#  [0.80141032]
#  [0.73875742]
#  [0.37484134]
#  [0.77245619]
#  [0.34041243]
#  [0.29124223]
#  [0.64342482]]

# %%
plt.plot(x, '*-')
plt.show()

# %%
x = np.linspace(0, 100, 50)
y = np.power(x, 2)
plt.plot(x, y, '+-')
plt.show()

# %%
sns.set()
sns.lineplot(x=x, y=y)
plt.show()

# %% [markdown]
# # **Plotting Data from Dataset**

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('/content/machine_learning/Classification/mobile_cleaned.csv')
data.head()
# Out:
#    sim_type  aperture  gpu_rank  weight  stand_by_time  processor_frequency  \
# 0         0        12        55   155.0            250                  1.3
# 1         0         1        55   132.0            300                  1.3
# 2         0         9        55   142.0            329                  1.5
# 3         0         8        55   152.0            385                  1.3
# 4         1         1        55   234.0            385                  1.3
#
#    thickness  flash_type  front_camera_resolution  auto_focus  ...  \
# 0       10.5           5                     2.00           0  ...
# 1       10.6           5                     0.30           1  ...
# 2        8.5           5                     2.00           3  ...
# 3        8.0           5                     2.00           3  ...
# 4        7.9           5                     1.92           3  ...
#
#    micro_sd_slot  screen_pixel_density  water_proof_rate  phone_width  \
# 0              4                     2                 3         67.8
# 1              4                     4                 6         64.0
# 2              4                     9                 6         72.0
# 3              4                     1                 3         75.1
# 4              4                     1                 6         91.0
#
#    expandable_memory  version  usb_type  battery_capacity  processor_rank  \
# 0               64.0        5         3              2000             125
# 1               32.0        5         3              2000             165
# 2               32.0        6         3              2500             164
# 3               32.0        6         3              3000             165
# 4               32.0        6         3              3000             165
#
#    is_liked
# 0         1
# 1         1
# 2         0
# 3         1
# 4         0
#
# [5 rows x 40 columns]

# %%
data.describe()

# %% [markdown]
# # Uni-Variant

# %%
sns.countplot(x ='sim_type', data = data)
plt.show()

# %%
sns.distplot(data["stand_by_time"])
plt.show()

# %%
sns.histplot(data=data, x="stand_by_time")
plt.show()

# %% [markdown]
# # Bi-Variant

# %%
ax = sns.scatterplot(x="stand_by_time", y="battery_capacity", data=data)
plt.show()

# %%
#Minimum, 25,50,75, max
ax = sns.boxplot(x="is_liked", y="battery_capacity", data=data)
plt.show()
#Minimum = Q1–1.5 * IQR and Maximum = Q3 + 1.5 * IQR

# %%
ax = sns.boxplot(x = "expandable_memory", y = "price", data=data)
plt.show()

# %% [markdown]
# # Multi-Variant

# %%
ax = sns.violinplot(x='expandable_memory', y='price', data=data,
               hue='is_liked', split=True)
plt.show()

# %%
ax = sns.scatterplot(x = "stand_by_time", y = "battery_capacity", hue="thickness", data=data)
plt.show()

# %%
dataframe = pd.read_csv("machine_learning/Machine_learning/2_IRIS/iris.csv")
print(dataframe.head())


ax = sns.scatterplot(x="petal.length", y="petal.width",hue="Variety",size = "sepal.width",data=dataframe)
plt.show()

# %%
ax = sns.swarmplot(x='sepal.length', y='Variety', data=dataframe)

# %%
sns.pairplot(dataframe[['petal.length','petal.width','sepal.length','sepal.width']])
plt.show()

# %%
sns.pairplot(dataframe, hue='Variety')
plt.show()
